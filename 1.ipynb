# %%
import matplotlib.pyplot as plt

# %%
a=[1,2,3]
b=[4,5,6]
plt.plot(a,b)
plt.show()

# %%
a=[1,2,3]
b=[4,5,6]
plt.scatter(a,b)
plt.show()

# %%
a=[1,2,3]
b=[4,5,6]
plt.plot([1,2,3,5,6], [1, 2, 3, 4, 6])
plt.axis([0, 8, 0, 10])
plt.show()

# %%
plt.bar([1.1,2.1,3.1,4.1],[10,20,30,40],label='BarPlot',width=0.3,color='r')
plt.bar([1.5,2.5,3.5,4.5],[20,30,40,50],label='BarPlot2',width=0.3,color='y')
plt.xticks(rotation=45,color='b')
plt.yticks(rotation=45,color='b')
plt.xlabel('X',color='b')
plt.ylabel('Y',color='b',rotation=90)
plt.title('Y/X')
plt.legend()
plt.show()

# %%
pop = [22,55,62,45,21,22,34,42,42,4,2,8]
bins = [1,10,20,30,40,50]
plt.hist(pop, bins, rwidth=0.6)
# Out:
# (array([3., 0., 3., 1., 3.]),
#  array([ 1., 10., 20., 30., 40., 50.]),
#  <BarContainer object of 5 artists>)
